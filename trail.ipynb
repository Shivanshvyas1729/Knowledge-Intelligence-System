# %%
from langchain.chains import create_history_aware_retriever
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langchain.chains import create_history_aware_retriever
#
# ImportError: cannot import name 'create_history_aware_retriever' from 'langchain.chains' (c:\Users\DELL\miniconda3\envs\llmapp\Lib\site-packages\langchain\chains\__init__.py)

# %%
from langchain_classic.chains import  create_retrieval_chain, create_history_aware_retriever

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.3.11

# %%
from langchain_classic.chains import  create_retrieval_chain, create_history_aware_retriever
